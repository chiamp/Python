# %%
from random_sentence_generator_final import *

run()
# Out:
# What is the string with 100% fitness? marcus
# How many individuals/strings per generation? 100
# How many individuals/strings survive to reproduce in the next generation? 5
# What are the chances of a string mutating? 40
# To what extent can a mutation mutate? 40
# Choose the power of the offspring distribution. 2
# Choose how far the offspring distribution is translated to the right. 2
# Choose how far the offspring distribution is translated upwards. 2
#
# Generation 0
# ...
